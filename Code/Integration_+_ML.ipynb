# %%
import pandas as pd
import numpy as np
import io
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
oildf = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/OilData_Clean.csv")
co2df = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/CO2_Clean.csv")
gasdf = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/Gas_Consumption_Clean.csv")
tempbycountry = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/GlobalLandTemperaturesByCountry.csv")
greenhousedf = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/GreenhouseGasClean.csv")
energydf = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/Primary-energy-consumption-from-fossilfuels-nuclear-renewables.csv")
coaldf = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/Coal_Clean.csv")

# %%
co2df= co2df.rename(columns={"Year":'year'})
gasdf= gasdf.rename(columns={"Year":'year'})
tempbycountry = tempbycountry.rename(columns={"DateTime":"year"})
energydf = energydf.rename(columns={"Year":"year"})

# %%
def remove_Unknown(df):
  df = df[df["short_name"].str.contains("Unknown")==False]
  return df

# %%
gasdf = remove_Unknown(gasdf)
oildf = remove_Unknown(oildf)
tempbycountry = remove_Unknown(tempbycountry)
co2df = remove_Unknown(co2df)
greenhousedf = remove_Unknown(greenhousedf)
energydf = remove_Unknown(energydf)
coaldf = remove_Unknown(coaldf)
gasdf.head()
# Out:
#     Unnamed: 0  Country  year  Gas Consumption - TWh short_name
# 56          56  Algeria  1965               7.430500    Algeria
# 57          57  Algeria  1966               7.719250    Algeria
# 58          58  Algeria  1967               7.488250    Algeria
# 59          59  Algeria  1968               7.873250    Algeria
# 60          60  Algeria  1969              10.351688    Algeria

# %%
def add_key(df):
  df["key"] = df["year"].astype(str) + df['short_name']
  return df

# %%
oildf2 = add_key(oildf)
co2df2 = add_key(co2df)
gasdf2 = add_key(gasdf)
tempbycountry2 = add_key(tempbycountry)
greenhousedf2 = add_key(greenhousedf)
energydf2 = add_key(energydf)
coaldf2 = add_key(coaldf)

# %%
oildf.head()
# Out:
#    Unnamed: 0        Country  year value     short_name                key
# 0         223  United States  1992  7171  United States  1992United States
# 1         224   Saudi Arabia  1992  8332   Saudi Arabia   1992Saudi Arabia
# 2         225         Russia  1992  7632         Russia         1992Russia
# 3         226         Canada  1992  1605         Canada         1992Canada
# 4         227           Iraq  1992   425           Iraq           1992Iraq

# %%
oildf.describe()
# Out:
#         Unnamed: 0         year
# count  5778.000000  5778.000000
# mean   3229.640187  2005.000000
# std    1738.180584     7.789555
# min     223.000000  1992.000000
# 25%    1722.250000  1998.000000
# 50%    3229.500000  2005.000000
# 75%    4736.750000  2012.000000
# max    6238.000000  2018.000000

# %%
co2df.head()
# Out:
#    Unnamed: 0  year  ...      short_name                 key
# 0           0  1751  ...  United Kingdom  1751United Kingdom
# 1           1  1752  ...  United Kingdom  1752United Kingdom
# 2           2  1753  ...  United Kingdom  1753United Kingdom
# 3           3  1754  ...  United Kingdom  1754United Kingdom
# 4           4  1755  ...  United Kingdom  1755United Kingdom
#
# [5 rows x 13 columns]

# %%
greenhousedf.describe()
# Out:
#         Unnamed: 0  ...  unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent
# count  1049.000000  ...                                          50.000000
# mean    542.446139  ...                                        3655.015200
# std     311.425814  ...                                        2764.998077
# min       0.000000  ...                                         151.950000
# 25%     262.000000  ...                                         821.710000
# 50%     549.000000  ...                                        4158.530000
# 75%     811.000000  ...                                        5535.937500
# max    1073.000000  ...                                        9449.890000
#
# [8 rows x 12 columns]

# %%
energydf.describe()
# Out:
#         Unnamed: 0  ...  Nuclear (% sub energy)
# count  4064.000000  ...             4064.000000
# mean   2149.904281  ...                3.053229
# std    1214.960616  ...                6.750992
# min      55.000000  ...                0.000000
# 25%    1070.750000  ...                0.000000
# 50%    2141.500000  ...                0.000000
# 75%    3212.250000  ...                1.380500
# max    4228.000000  ...               41.707000
#
# [8 rows x 5 columns]

# %%
tempbycountry.describe()
# Out:
#          Unnamed: 0  ...  AverageTemperatureUncertainty
# count  46398.000000  ...                   44213.000000
# mean   24195.594702  ...                       1.038533
# std    13836.222923  ...                       1.074509
# min        0.000000  ...                       0.115083
# 25%    12150.250000  ...                       0.350917
# 50%    24151.500000  ...                       0.600833
# 75%    36289.750000  ...                       1.243667
# max    48242.000000  ...                       7.281667
#
# [8 rows x 4 columns]

# %%
greenhousedf = greenhousedf.loc[(greenhousedf['year'] > 1991) & (greenhousedf['year'] < 2013)]

# %%
def cutyears(df):
  df = df.loc[(df['year'] > 1991) & (df['year'] < 2014)]
  return df

# %%
greenhousedf = cutyears(greenhousedf)
tempbycountry = cutyears(tempbycountry)
energydf = cutyears(energydf)
coaldf = cutyears(coaldf)
co2df = cutyears(co2df)
gasdf = cutyears(gasdf)

# %%
#co2df.describe()

# %%
#co2df.head()

# %%
#gasdf.head()

# %%
#tempbycountry.head()

# %%
#greenhousedf.head()

# %%
#energydf.head()

# %%
#coaldf.info()

# %%
#energydf.info()

# %%
from functools import reduce

# %%
#co2df2.info()

# %%
#co2df.info()

# %%
dfs = [co2df, energydf, greenhousedf,gasdf, oildf, tempbycountry]
# co2df2, energydf2, greenhousedf2,tempbycountry2,gasdf2, co2df2, oildf2

# %%
df_final = reduce(lambda left,right: pd.merge(left,right, on="key"), dfs)

# %%
#pd.set_option('max_rows', 2000)

# %%
#df_final

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 903 entries, 0 to 902
# Data columns (total 51 columns):
#  #   Column                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                          --------------  -----
#  0   Unnamed: 0_x                                                                                                    903 non-null    int64
#  1   year_x                                                                                                          903 non-null    int64
#  2   Country_x                                                                                                       903 non-null    object
#  3   Total                                                                                                           903 non-null    int64
#  4   Solid Fuel                                                                                                      903 non-null    int64
#  5   Liquid Fuel                                                                                                     903 non-null    int64
#  6   Gas Fuel                                                                                                        903 non-null    int64
#  7   Cement                                                                                                          903 non-null    int64
#  8   Gas Flaring                                                                                                     903 non-null    int64
#  9   Per Capita                                                                                                      903 non-null    float64
#  10  Bunker fuels (Not in Total)                                                                                     903 non-null    int64
#  11  short_name_x                                                                                                    903 non-null    object
#  12  key                                                                                                             903 non-null    object
#  13  Unnamed: 0_y                                                                                                    903 non-null    int64
#  14  Country_y                                                                                                       903 non-null    object
#  15  Code                                                                                                            903 non-null    object
#  16  year_y                                                                                                          903 non-null    int64
#  17  Fossil fuels (% sub energy)                                                                                     903 non-null    float64
#  18  Renewables (% sub energy)                                                                                       903 non-null    float64
#  19  Nuclear (% sub energy)                                                                                          903 non-null    float64
#  20  short_name_y                                                                                                    903 non-null    object
#  21  Unnamed: 0_x                                                                                                    903 non-null    int64
#  22  country_or_area                                                                                                 903 non-null    object
#  23  year_x                                                                                                          903 non-null    int64
#  24  carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent   903 non-null    float64
#  25  greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent                 798 non-null    float64
#  26  greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  903 non-null    float64
#  27  hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent                                                   845 non-null    float64
#  28  methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent          903 non-null    float64
#  29  nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent                                                  227 non-null    float64
#  30  nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent    903 non-null    float64
#  31  perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent                                                     727 non-null    float64
#  32  sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent                                                  885 non-null    float64
#  33  unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent      42 non-null     float64
#  34  short_name_x                                                                                                    903 non-null    object
#  35  Unnamed: 0_y                                                                                                    903 non-null    int64
#  36  Country_x                                                                                                       903 non-null    object
#  37  year_y                                                                                                          903 non-null    int64
#  38  Gas Consumption - TWh                                                                                           903 non-null    float64
#  39  short_name_y                                                                                                    903 non-null    object
#  40  Unnamed: 0_x                                                                                                    903 non-null    int64
#  41  Country_y                                                                                                       903 non-null    object
#  42  year_x                                                                                                          903 non-null    int64
#  43  value                                                                                                           903 non-null    object
#  44  short_name_x                                                                                                    903 non-null    object
#  45  Unnamed: 0_y                                                                                                    903 non-null    int64
#  46  Country                                                                                                         903 non-null    object
#  47  year_y                                                                                                          903 non-null    int64
#  48  AverageTemperature                                                                                              903 non-null    float64
#  49  AverageTemperatureUncertainty                                                                                   903 non-null    float64
#  50  short_name_y                                                                                                    903 non-null    object
# dtypes: float64(17), int64(19), object(15)
# memory usage: 366.8+ KB

# %%
x = df_final.drop(columns=["Unnamed: 0_x", "Country_x", "Unnamed: 0_y", "Country_y", "Code", "year_y", "short_name_y", "country_or_area", "year_x", "Unnamed: 0_x", "Country_x", "year_y","Country_y", "year_y", "Country_y", "short_name_y" ], axis=1)

# %%
x.head()
# Out:
#    Total  Solid Fuel  ...  AverageTemperature  AverageTemperatureUncertainty
# 0  73080       41244  ...           21.932583                       0.227917
# 1  15451        3477  ...            7.615583                       0.257000
# 2  23839        2149  ...            7.132000                       0.242667
# 3  30534        9171  ...           10.489250                       0.260333
# 4  14782        8252  ...           11.021750                       0.332000
#
# [5 rows x 30 columns]

# %%
#y = x[["AverageTemperature"]]

# %%
train = x

# %%
train
# Out:
#        Total  Solid Fuel  ...  AverageTemperature  AverageTemperatureUncertainty
# 0      73080       41244  ...           21.932583                       0.227917
# 1      15451        3477  ...            7.615583                       0.257000
# 2      23839        2149  ...            7.132000                       0.242667
# 3      30534        9171  ...           10.489250                       0.260333
# 4      14782        8252  ...           11.021750                       0.332000
# ..       ...         ...  ...                 ...                            ...
# 898    89872       36927  ...           12.854417                       0.335000
# 899    80663       43570  ...            9.290667                       0.303667
# 900   127781       39717  ...            9.037417                       0.264500
# 901   127781       39717  ...            9.185167                       0.249917
# 902  1396083      443904  ...           10.261083                       0.215500
#
# [903 rows x 30 columns]

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(train)
# Out:
# Your selected dataframe has 30 columns.
# There are 6 columns that have missing values.
#                                                     Missing Values  % of Total Values
# unspecified_mix_of_hydrofluorocarbons_hfcs_and_...             861               95.3
# nitrogen_trifluoride_nf3_emissions_in_kilotonne...             676               74.9
# perfluorocarbons_pfcs_emissions_in_kilotonne_co...             176               19.5
# greenhouse_gas_ghgs_emissions_including_indirec...             105               11.6
# hydrofluorocarbons_hfcs_emissions_in_kilotonne_...              58                6.4
# sulphur_hexafluoride_sf6_emissions_in_kilotonne...              18                2.0

# %%
train = train.drop(["unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent", "nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent"], axis= 1)

# %%
train
# Out:
#        Total  Solid Fuel  ...  AverageTemperature  AverageTemperatureUncertainty
# 0      73080       41244  ...           21.932583                       0.227917
# 1      15451        3477  ...            7.615583                       0.257000
# 2      23839        2149  ...            7.132000                       0.242667
# 3      30534        9171  ...           10.489250                       0.260333
# 4      14782        8252  ...           11.021750                       0.332000
# ..       ...         ...  ...                 ...                            ...
# 898    89872       36927  ...           12.854417                       0.335000
# 899    80663       43570  ...            9.290667                       0.303667
# 900   127781       39717  ...            9.037417                       0.264500
# 901   127781       39717  ...            9.185167                       0.249917
# 902  1396083      443904  ...           10.261083                       0.215500
#
# [903 rows x 28 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 903 entries, 0 to 902
# Data columns (total 28 columns):
#  #   Column                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                          --------------  -----
#  0   Total                                                                                                           903 non-null    int64
#  1   Solid Fuel                                                                                                      903 non-null    int64
#  2   Liquid Fuel                                                                                                     903 non-null    int64
#  3   Gas Fuel                                                                                                        903 non-null    int64
#  4   Cement                                                                                                          903 non-null    int64
#  5   Gas Flaring                                                                                                     903 non-null    int64
#  6   Per Capita                                                                                                      903 non-null    float64
#  7   Bunker fuels (Not in Total)                                                                                     903 non-null    int64
#  8   short_name_x                                                                                                    903 non-null    object
#  9   key                                                                                                             903 non-null    object
#  10  Fossil fuels (% sub energy)                                                                                     903 non-null    float64
#  11  Renewables (% sub energy)                                                                                       903 non-null    float64
#  12  Nuclear (% sub energy)                                                                                          903 non-null    float64
#  13  carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent   903 non-null    float64
#  14  greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent                 798 non-null    float64
#  15  greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  903 non-null    float64
#  16  hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent                                                   845 non-null    float64
#  17  methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent          903 non-null    float64
#  18  nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent    903 non-null    float64
#  19  perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent                                                     727 non-null    float64
#  20  sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent                                                  885 non-null    float64
#  21  short_name_x                                                                                                    903 non-null    object
#  22  Gas Consumption - TWh                                                                                           903 non-null    float64
#  23  value                                                                                                           903 non-null    object
#  24  short_name_x                                                                                                    903 non-null    object
#  25  Country                                                                                                         903 non-null    object
#  26  AverageTemperature                                                                                              903 non-null    float64
#  27  AverageTemperatureUncertainty                                                                                   903 non-null    float64
# dtypes: float64(15), int64(7), object(6)
# memory usage: 204.6+ KB

# %%
#Prediction #greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent

# %%
train["countrycount"] = train[['key']].iloc[:3]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
names = []

for i in train["key"]:
    names.append(i[4:])

train["short_name"] = names

# %%
train
# Out:
#        Total  Solid Fuel  ...   countrycount      short_name
# 0      73080       41244  ...  1992Australia       Australia
# 1      15451        3477  ...    1992Austria         Austria
# 2      23839        2149  ...    1992Belarus         Belarus
# 3      30534        9171  ...            NaN         Belgium
# 4      14782        8252  ...            NaN        Bulgaria
# ..       ...         ...  ...            ...             ...
# 898    89872       36927  ...            NaN          Turkey
# 899    80663       43570  ...            NaN         Ukraine
# 900   127781       39717  ...            NaN  United Kingdom
# 901   127781       39717  ...            NaN  United Kingdom
# 902  1396083      443904  ...            NaN   United States
#
# [903 rows x 30 columns]

# %%
# get rid of the short names 
# take features, 80 - 20 split 
# predict temperature off of features

# %%
train = train.drop_duplicates(subset=["key"])

# %%
train["short_name"].value_counts()
# Out:
# Netherlands       21
# Ireland           21
# Norway            21
# Estonia           21
# Romania           21
# Czech Republic    21
# Slovakia          21
# Japan             21
# Lithuania         21
# Bulgaria          21
# United Kingdom    21
# Italy             21
# Slovenia          21
# Belarus           21
# Spain             21
# Germany           21
# Poland            21
# New Zealand       21
# Sweden            21
# Luxembourg        21
# Hungary           21
# Australia         21
# Finland           21
# Canada            21
# Iceland           21
# Latvia            21
# Portugal          21
# Austria           21
# France            21
# Croatia           21
# Ukraine           21
# Switzerland       21
# Belgium           21
# Greece            21
# Russia            21
# Turkey            21
# Cyprus            21
# United States     21
# Denmark           21
# Name: short_name, dtype: int64

# %%
train
# Out:
#        Total  Solid Fuel  ...   countrycount      short_name
# 0      73080       41244  ...  1992Australia       Australia
# 1      15451        3477  ...    1992Austria         Austria
# 2      23839        2149  ...    1992Belarus         Belarus
# 3      30534        9171  ...            NaN         Belgium
# 4      14782        8252  ...            NaN        Bulgaria
# ..       ...         ...  ...            ...             ...
# 897    10301         126  ...            NaN     Switzerland
# 898    89872       36927  ...            NaN          Turkey
# 899    80663       43570  ...            NaN         Ukraine
# 900   127781       39717  ...            NaN  United Kingdom
# 902  1396083      443904  ...            NaN   United States
#
# [819 rows x 30 columns]

# %%
train = train.drop_duplicates(subset=["key"])

# %%
train
# Out:
#        Total  Solid Fuel  ...   countrycount      short_name
# 0      73080       41244  ...  1992Australia       Australia
# 1      15451        3477  ...    1992Austria         Austria
# 2      23839        2149  ...    1992Belarus         Belarus
# 3      30534        9171  ...            NaN         Belgium
# 4      14782        8252  ...            NaN        Bulgaria
# ..       ...         ...  ...            ...             ...
# 897    10301         126  ...            NaN     Switzerland
# 898    89872       36927  ...            NaN          Turkey
# 899    80663       43570  ...            NaN         Ukraine
# 900   127781       39717  ...            NaN  United Kingdom
# 902  1396083      443904  ...            NaN   United States
#
# [819 rows x 30 columns]

# %%
train.describe()
# Out:
#               Total  ...  AverageTemperatureUncertainty
# count  8.190000e+02  ...                     819.000000
# mean   9.656775e+04  ...                       0.250950
# std    2.433446e+05  ...                       0.089003
# min    4.910000e+02  ...                       0.127917
# 25%    9.815500e+03  ...                       0.208542
# 50%    1.710700e+04  ...                       0.233250
# 75%    8.873400e+04  ...                       0.264875
# max    1.578873e+06  ...                       0.948833
#
# [8 rows x 22 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 902
# Data columns (total 30 columns):
#  #   Column                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                          --------------  -----
#  0   Total                                                                                                           819 non-null    int64
#  1   Solid Fuel                                                                                                      819 non-null    int64
#  2   Liquid Fuel                                                                                                     819 non-null    int64
#  3   Gas Fuel                                                                                                        819 non-null    int64
#  4   Cement                                                                                                          819 non-null    int64
#  5   Gas Flaring                                                                                                     819 non-null    int64
#  6   Per Capita                                                                                                      819 non-null    float64
#  7   Bunker fuels (Not in Total)                                                                                     819 non-null    int64
#  8   short_name_x                                                                                                    819 non-null    object
#  9   key                                                                                                             819 non-null    object
#  10  Fossil fuels (% sub energy)                                                                                     819 non-null    float64
#  11  Renewables (% sub energy)                                                                                       819 non-null    float64
#  12  Nuclear (% sub energy)                                                                                          819 non-null    float64
#  13  carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent   819 non-null    float64
#  14  greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent                 735 non-null    float64
#  15  greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  819 non-null    float64
#  16  hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent                                                   761 non-null    float64
#  17  methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent          819 non-null    float64
#  18  nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent    819 non-null    float64
#  19  perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent                                                     645 non-null    float64
#  20  sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent                                                  801 non-null    float64
#  21  short_name_x                                                                                                    819 non-null    object
#  22  Gas Consumption - TWh                                                                                           819 non-null    float64
#  23  value                                                                                                           819 non-null    object
#  24  short_name_x                                                                                                    819 non-null    object
#  25  Country                                                                                                         819 non-null    object
#  26  AverageTemperature                                                                                              819 non-null    float64
#  27  AverageTemperatureUncertainty                                                                                   819 non-null    float64
#  28  countrycount                                                                                                    3 non-null      object
#  29  short_name                                                                                                      819 non-null    object
# dtypes: float64(15), int64(7), object(8)
# memory usage: 198.4+ KB

# %%
train = train.drop(train.columns[21], axis =1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 902
# Data columns (total 27 columns):
#  #   Column                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                          --------------  -----
#  0   Total                                                                                                           819 non-null    int64
#  1   Solid Fuel                                                                                                      819 non-null    int64
#  2   Liquid Fuel                                                                                                     819 non-null    int64
#  3   Gas Fuel                                                                                                        819 non-null    int64
#  4   Cement                                                                                                          819 non-null    int64
#  5   Gas Flaring                                                                                                     819 non-null    int64
#  6   Per Capita                                                                                                      819 non-null    float64
#  7   Bunker fuels (Not in Total)                                                                                     819 non-null    int64
#  8   key                                                                                                             819 non-null    object
#  9   Fossil fuels (% sub energy)                                                                                     819 non-null    float64
#  10  Renewables (% sub energy)                                                                                       819 non-null    float64
#  11  Nuclear (% sub energy)                                                                                          819 non-null    float64
#  12  carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent   819 non-null    float64
#  13  greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent                 735 non-null    float64
#  14  greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  819 non-null    float64
#  15  hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent                                                   761 non-null    float64
#  16  methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent          819 non-null    float64
#  17  nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent    819 non-null    float64
#  18  perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent                                                     645 non-null    float64
#  19  sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent                                                  801 non-null    float64
#  20  Gas Consumption - TWh                                                                                           819 non-null    float64
#  21  value                                                                                                           819 non-null    object
#  22  Country                                                                                                         819 non-null    object
#  23  AverageTemperature                                                                                              819 non-null    float64
#  24  AverageTemperatureUncertainty                                                                                   819 non-null    float64
#  25  countrycount                                                                                                    3 non-null      object
#  26  short_name                                                                                                      819 non-null    object
# dtypes: float64(15), int64(7), object(5)
# memory usage: 179.2+ KB

# %%
train
# Out:
#        Total  Solid Fuel  ...   countrycount      short_name
# 0      73080       41244  ...  1992Australia       Australia
# 1      15451        3477  ...    1992Austria         Austria
# 2      23839        2149  ...    1992Belarus         Belarus
# 3      30534        9171  ...            NaN         Belgium
# 4      14782        8252  ...            NaN        Bulgaria
# ..       ...         ...  ...            ...             ...
# 897    10301         126  ...            NaN     Switzerland
# 898    89872       36927  ...            NaN          Turkey
# 899    80663       43570  ...            NaN         Ukraine
# 900   127781       39717  ...            NaN  United Kingdom
# 902  1396083      443904  ...            NaN   United States
#
# [819 rows x 27 columns]

# %%
final = train.drop(["carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent",	"greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent", "greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent", "hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent", "methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent", "nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent", "perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent", "sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent" ], axis= 1)

# %%
final= final.drop(["countrycount"],axis= 1)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 902
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Total                          819 non-null    int64
#  1   Solid Fuel                     819 non-null    int64
#  2   Liquid Fuel                    819 non-null    int64
#  3   Gas Fuel                       819 non-null    int64
#  4   Cement                         819 non-null    int64
#  5   Gas Flaring                    819 non-null    int64
#  6   Per Capita                     819 non-null    float64
#  7   Bunker fuels (Not in Total)    819 non-null    int64
#  8   key                            819 non-null    object
#  9   Fossil fuels (% sub energy)    819 non-null    float64
#  10  Renewables (% sub energy)      819 non-null    float64
#  11  Nuclear (% sub energy)         819 non-null    float64
#  12  Gas Consumption - TWh          819 non-null    float64
#  13  value                          819 non-null    object
#  14  Country                        819 non-null    object
#  15  AverageTemperature             819 non-null    float64
#  16  AverageTemperatureUncertainty  819 non-null    float64
#  17  short_name                     819 non-null    object
# dtypes: float64(7), int64(7), object(4)
# memory usage: 121.6+ KB

# %%
y2 = train[['greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent']]

# %%
y2
# Out:
#      greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent
# 0                                            423080.11
# 1                                             75931.00
# 2                                            116588.69
# 3                                            148384.73
# 4                                             77199.35
# ..                                                 ...
# 897                                           51637.52
# 898                                          447452.33
# 899                                          409531.35
# 900                                          582946.59
# 902                                         6643010.58
#
# [819 rows x 1 columns]

# %%
y2.describe()
# Out:
#        greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent
# count                                       8.190000e+02
# mean                                        4.684134e+05
# std                                         1.162000e+06
# min                                         3.328370e+03
# 25%                                         5.388886e+04
# 50%                                         8.366629e+04
# 75%                                         4.336556e+05
# max                                         7.422208e+06

# %%
y2.median()
# Out:
# greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent    83666.29
# dtype: float64

# %%
y2.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#       greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent
# count                                          819.00000
# mean                                        468413.43891
# std                                        1162000.23758
# min                                           3328.37000
# 25%                                          53888.86000
# 50%                                          83666.29000
# 75%                                         433655.60000
# max                                        7422207.96000

# %%
#train["class"] = pd.cut(train['greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent'], bins=[3327, 53889, 83667, 433655, float('inf')], labels = ["min", "low", "med", "high"])

# %%
train["class"] = pd.cut(train['greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent'], bins=[3327, 53889, 83667, 433655, float('inf')], labels = [0, 1, 2, 3])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
train
# Out:
#        Total  Solid Fuel  Liquid Fuel  ...   countrycount      short_name  class
# 0      73080       41244        22021  ...  1992Australia       Australia      2
# 1      15451        3477         7929  ...    1992Austria         Austria      1
# 2      23839        2149        12122  ...    1992Belarus         Belarus      2
# 3      30534        9171        14613  ...            NaN         Belgium      2
# 4      14782        8252         3955  ...            NaN        Bulgaria      1
# ..       ...         ...          ...  ...            ...             ...    ...
# 897    10301         126         7730  ...            NaN     Switzerland      0
# 898    89872       36927        20984  ...            NaN          Turkey      3
# 899    80663       43570         8877  ...            NaN         Ukraine      2
# 900   127781       39717        44872  ...            NaN  United Kingdom      3
# 902  1396083      443904       566582  ...            NaN   United States      3
#
# [819 rows x 28 columns]

# %%
missing_values_table(train)
#fill with mode/median/mean 
# get rid of countrycount 
# ready for prediction
# Out:
# Your selected dataframe has 28 columns.
# There are 5 columns that have missing values.
#                                                     Missing Values  % of Total Values
# countrycount                                                   816               99.6
# perfluorocarbons_pfcs_emissions_in_kilotonne_co...             174               21.2
# greenhouse_gas_ghgs_emissions_including_indirec...              84               10.3
# hydrofluorocarbons_hfcs_emissions_in_kilotonne_...              58                7.1
# sulphur_hexafluoride_sf6_emissions_in_kilotonne...              18                2.2

# %%
missing_values_table(y2)
# Out:
# Your selected dataframe has 1 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
#train = train.drop(["countrycount", "greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent"], axis=1)

# %%
#train["filled_perf_co2"] = train.groupby("Country").transform(lambda x: x.fillna(x.mean()))["perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent"]
#train["perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent"].fillna(train.groupby("Country")["perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent"].transform("mean"), inplace = True)
#test = train["perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent"].fillna(0)
#test2 = train.groupby(["Country"], sort=False)['perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent'].apply(lambda x: x.fillna(x.mean()))

# %%
mean = train["perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent"].mean()
#mean = train.groupby(["Country"])['perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent'].mean().values[0]
train["perfluorocarbons_co2"] = train["perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent"].fillna(value = mean)
# fills with mean 
# not the best way to do it but grouping was not working because maybe some countries have no values for this 
# consider this dropping this columns 
#
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
mean2 = train["hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent"].mean()
train["hyrdofluorocarbons_co2"] = train["hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent"].fillna(value = mean2)
mean3 = train["sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent"].mean()
train["sulphur_co2"] = train["sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent"].fillna(value = mean3)

# %%
# convert country to ID/number
df = pd.factorize(train["Country"])

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
train["Country"].unique()
# Out:
# array(['Australia', 'Austria', 'Belarus', 'Belgium', 'Bulgaria', 'Canada',
#        'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Japan', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Romania', 'Russia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom',
#        'United States'], dtype=object)

# %%
train["countries_num"] = label_encoder.fit_transform(train["Country"])

# %%
train
# Out:
#        Total  Solid Fuel  ...  sulphur_co2  countries_num
# 0      73080       41244  ...   246.860000              0
# 1      15451        3477  ...   656.270000              1
# 2      23839        2149  ...  1047.838602              2
# 3      30534        9171  ...  1652.690000              3
# 4      14782        8252  ...     4.130000              4
# ..       ...         ...  ...          ...            ...
# 897    10301         126  ...   208.910000             34
# 898    89872       36927  ...   926.430000             35
# 899    80663       43570  ...    10.990000             36
# 900   127781       39717  ...   582.650000             37
# 902  1396083      443904  ...  7581.760000             38
#
# [819 rows x 32 columns]

# %%
train = train.drop(["countrycount", "greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent",
                    "hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent",
                    "sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent", 
                    "sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent", "short_name","Country", "key", "perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent" ], axis=1)

# %%
train.head()
# Out:
#    Total  Solid Fuel  ...  sulphur_co2  countries_num
# 0  73080       41244  ...   246.860000              0
# 1  15451        3477  ...   656.270000              1
# 2  23839        2149  ...  1047.838602              2
# 3  30534        9171  ...  1652.690000              3
# 4  14782        8252  ...     4.130000              4
#
# [5 rows x 24 columns]

# %%
train["coalval"] = train['value'].replace('--', 0, regex =True)

# %%
train["coalval"] = train["coalval"].apply(pd.to_numeric, downcast="float", errors="coerce")

# %%
train["class"] = train["class"].apply(pd.to_numeric, errors="coerce")

# %%
train = train.drop(["value"], axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 902
# Data columns (total 24 columns):
#  #   Column                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                          --------------  -----
#  0   Total                                                                                                           819 non-null    int64
#  1   Solid Fuel                                                                                                      819 non-null    int64
#  2   Liquid Fuel                                                                                                     819 non-null    int64
#  3   Gas Fuel                                                                                                        819 non-null    int64
#  4   Cement                                                                                                          819 non-null    int64
#  5   Gas Flaring                                                                                                     819 non-null    int64
#  6   Per Capita                                                                                                      819 non-null    float64
#  7   Bunker fuels (Not in Total)                                                                                     819 non-null    int64
#  8   Fossil fuels (% sub energy)                                                                                     819 non-null    float64
#  9   Renewables (% sub energy)                                                                                       819 non-null    float64
#  10  Nuclear (% sub energy)                                                                                          819 non-null    float64
#  11  carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent   819 non-null    float64
#  12  greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  819 non-null    float64
#  13  methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent          819 non-null    float64
#  14  nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent    819 non-null    float64
#  15  Gas Consumption - TWh                                                                                           819 non-null    float64
#  16  AverageTemperature                                                                                              819 non-null    float64
#  17  AverageTemperatureUncertainty                                                                                   819 non-null    float64
#  18  class                                                                                                           819 non-null    category
#  19  perfluorocarbons_co2                                                                                            819 non-null    float64
#  20  hyrdofluorocarbons_co2                                                                                          819 non-null    float64
#  21  sulphur_co2                                                                                                     819 non-null    float64
#  22  countries_num                                                                                                   819 non-null    int64
#  23  coalval                                                                                                         819 non-null    float64
# dtypes: category(1), float64(15), int64(8)
# memory usage: 154.5 KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 902
# Data columns (total 24 columns):
#  #   Column                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                          --------------  -----
#  0   Total                                                                                                           819 non-null    int64
#  1   Solid Fuel                                                                                                      819 non-null    int64
#  2   Liquid Fuel                                                                                                     819 non-null    int64
#  3   Gas Fuel                                                                                                        819 non-null    int64
#  4   Cement                                                                                                          819 non-null    int64
#  5   Gas Flaring                                                                                                     819 non-null    int64
#  6   Per Capita                                                                                                      819 non-null    float64
#  7   Bunker fuels (Not in Total)                                                                                     819 non-null    int64
#  8   Fossil fuels (% sub energy)                                                                                     819 non-null    float64
#  9   Renewables (% sub energy)                                                                                       819 non-null    float64
#  10  Nuclear (% sub energy)                                                                                          819 non-null    float64
#  11  carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent   819 non-null    float64
#  12  greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  819 non-null    float64
#  13  methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent          819 non-null    float64
#  14  nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent    819 non-null    float64
#  15  Gas Consumption - TWh                                                                                           819 non-null    float64
#  16  AverageTemperature                                                                                              819 non-null    float64
#  17  AverageTemperatureUncertainty                                                                                   819 non-null    float64
#  18  class                                                                                                           819 non-null    category
#  19  perfluorocarbons_co2                                                                                            819 non-null    float64
#  20  hyrdofluorocarbons_co2                                                                                          819 non-null    float64
#  21  sulphur_co2                                                                                                     819 non-null    float64
#  22  countries_num                                                                                                   819 non-null    int64
#  23  coalval                                                                                                         819 non-null    float64
# dtypes: category(1), float64(15), int64(8)
# memory usage: 154.5 KB

# %%
x = train.drop(["greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent", "class"], axis =1 )

# %%
y = train[["class"]]

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 902
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   819 non-null    category
# dtypes: category(1)
# memory usage: 7.4 KB

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 902
# Data columns (total 22 columns):
#  #   Column                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                         --------------  -----
#  0   Total                                                                                                          819 non-null    int64
#  1   Solid Fuel                                                                                                     819 non-null    int64
#  2   Liquid Fuel                                                                                                    819 non-null    int64
#  3   Gas Fuel                                                                                                       819 non-null    int64
#  4   Cement                                                                                                         819 non-null    int64
#  5   Gas Flaring                                                                                                    819 non-null    int64
#  6   Per Capita                                                                                                     819 non-null    float64
#  7   Bunker fuels (Not in Total)                                                                                    819 non-null    int64
#  8   Fossil fuels (% sub energy)                                                                                    819 non-null    float64
#  9   Renewables (% sub energy)                                                                                      819 non-null    float64
#  10  Nuclear (% sub energy)                                                                                         819 non-null    float64
#  11  carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  819 non-null    float64
#  12  methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent         819 non-null    float64
#  13  nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent   819 non-null    float64
#  14  Gas Consumption - TWh                                                                                          819 non-null    float64
#  15  AverageTemperature                                                                                             819 non-null    float64
#  16  AverageTemperatureUncertainty                                                                                  819 non-null    float64
#  17  perfluorocarbons_co2                                                                                           819 non-null    float64
#  18  hyrdofluorocarbons_co2                                                                                         819 non-null    float64
#  19  sulphur_co2                                                                                                    819 non-null    float64
#  20  countries_num                                                                                                  819 non-null    int64
#  21  coalval                                                                                                        819 non-null    float64
# dtypes: float64(14), int64(8)
# memory usage: 147.2 KB

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
dtree_model = DecisionTreeClassifier(max_depth = 2).fit(X_train, y_train)
dtree_predictions = dtree_model.predict(X_test)
dtree_pred_prob = dtree_model.predict_proba(X_test)
cm = confusion_matrix(y_test, dtree_predictions)
f1 = f1_score(y_test, dtree_predictions, average='micro')
print(cm, f1)
# Out:
# [[43  6  0  0]
#  [ 0 35  1  0]
#  [ 0  1 34  2]
#  [ 0  0  1 41]] 0.9329268292682927

# %%
print(cross_val_score(dtree_model, x, y, cv = 10))
# Out:
# [0.93902439 0.74390244 0.70731707 0.92682927 0.95121951 0.68292683
#  0.92682927 0.70731707 0.93902439 0.88888889]

# %%
cm = confusion_matrix(y_test, dtree_predictions)
f1 = f1_score(y_test, dtree_predictions, average='micro')
print("Confusion Matrix\n",cm)
print("Classification Report\n",(metrics.classification_report(y_test, dtree_predictions, digits=3)))
# Out:
# Confusion Matrix
#  [[43  6  0  0]
#  [ 0 35  1  0]
#  [ 0  1 34  2]
#  [ 0  0  1 41]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0      1.000     0.878     0.935        49
#            1      0.833     0.972     0.897        36
#            2      0.944     0.919     0.932        37
#            3      0.953     0.976     0.965        42
#
#     accuracy                          0.933       164
#    macro avg      0.933     0.936     0.932       164
# weighted avg      0.939     0.933     0.934       164

# %%
dtreescore = roc_auc_score(y_test, dtree_pred_prob, multi_class='ovr')
dtreernd = .977
dtreescore
# Out:
# 0.976700062002995

# %%
random_probs = [0 for i in range(len(y_test))]
fpr4, tpr4, thresh1 = roc_curve(y_test, dtree_pred_prob[:,1], pos_label=1)
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)
plt.plot(fpr4, tpr4, linestyle='--',color='green', label=f"Decision Tree AUC: {dtreernd}")
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Decision Tree ROC',dpi=300)
plt.show();

# %%
logreg = LogisticRegression(random_state=42, multi_class = "ovr", verbose=0)
logreg.fit(X_train, y_train)
predict = logreg.predict(X_test)
log_prob = logreg.predict_proba(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
#logreg2 = LogisticRegression(random_state=42, multi_class = "ovr")

# %%
cm = confusion_matrix(y_test, predict)
f1 = f1_score(y_test, predict, average='micro')
print("Confusion Matrix\n",cm)
print("Classification Report\n",(metrics.classification_report(y_test, predict, digits=3)))
# Out:
# Confusion Matrix
#  [[31  3  9  6]
#  [ 4 14  4 14]
#  [ 0  0 29  8]
#  [ 0  1  4 37]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0      0.886     0.633     0.738        49
#            1      0.778     0.389     0.519        36
#            2      0.630     0.784     0.699        37
#            3      0.569     0.881     0.692        42
#
#     accuracy                          0.677       164
#    macro avg      0.716     0.672     0.662       164
# weighted avg      0.723     0.677     0.669       164

# %%
crossvallog = cross_val_score(logreg, x, y, cv = 20)
crossvallog
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# array([0.53658537, 0.6097561 , 0.56097561, 0.63414634, 0.68292683,
#        0.68292683, 0.7804878 , 0.75609756, 0.70731707, 0.70731707,
#        0.68292683, 0.75609756, 0.70731707, 0.68292683, 0.68292683,
#        0.70731707, 0.63414634, 0.70731707, 0.70731707, 0.675     ])

# %%
crossvallog
# Out:
# array([0.53658537, 0.6097561 , 0.56097561, 0.63414634, 0.68292683,
#        0.68292683, 0.7804878 , 0.75609756, 0.70731707, 0.70731707,
#        0.68292683, 0.75609756, 0.70731707, 0.68292683, 0.68292683,
#        0.70731707, 0.63414634, 0.70731707, 0.70731707, 0.675     ])

# %%
logscore = (roc_auc_score(y_test, log_prob, multi_class='ovr')).round(2)
logscore
# Out:
# 0.92

# %%
from sklearn.metrics import roc_curve
fpr1, tpr1, thresh1 = roc_curve(y_test, log_prob[:,1], pos_label=1)
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label=f"Logistic Regression AUC: {logscore}")
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Log Reg ROC',dpi=300)
plt.show();

# %%
"""fpr = {}
tpr = {}
thresh ={}

n_class = 4

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, log_prob[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='Class 0 vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Class 1 vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Class 2 vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--',color='yellow', label='Class 3 vs Rest')
plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Multiclass ROC',dpi=300); """
# Out:
# "fpr = {}\ntpr = {}\nthresh ={}\n\nn_class = 4\n\nfor i in range(n_class):    \n    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, log_prob[:,i], pos_label=i)\n    \n# plotting    \nplt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='Class 0 vs Rest')\nplt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Class 1 vs Rest')\nplt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Class 2 vs Rest')\nplt.plot(fpr[3], tpr[3], linestyle='--',color='yellow', label='Class 3 vs Rest')\nplt.title('Multiclass ROC curve')\nplt.xlabel('False Positive Rate')\nplt.ylabel('True Positive rate')\nplt.legend(loc='best')\nplt.savefig('Multiclass ROC',dpi=300); "

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
rfpred = rf.predict(X_test)
rfpred_prob = rf.predict_proba(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
cm = confusion_matrix(y_test, rfpred)
f1 = f1_score(y_test, rfpred, average='micro')
print("Confusion Matrix\n",cm, "\n")
print("Classification Report\n",(metrics.classification_report(y_test, rfpred, digits=3)))
# Out:
# Confusion Matrix
#  [[47  2  0  0]
#  [ 0 36  0  0]
#  [ 0  1 36  0]
#  [ 0  0  0 42]]
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0      1.000     0.959     0.979        49
#            1      0.923     1.000     0.960        36
#            2      1.000     0.973     0.986        37
#            3      1.000     1.000     1.000        42
#
#     accuracy                          0.982       164
#    macro avg      0.981     0.983     0.981       164
# weighted avg      0.983     0.982     0.982       164

# %%
rfscore = roc_auc_score(y_test, rfpred_prob, multi_class='ovr')
rfscore
# Out:
# 0.9996277066080055

# %%
rfscoreround = ".99~"

# %%
fpr2, tpr2, thresh1 = roc_curve(y_test, rfpred_prob[:,1], pos_label=1)
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)
plt.plot(fpr2, tpr2, linestyle='--',color='green', label=f"Random Forest AUC: {rfscoreround}")
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('RandomForest ROC',dpi=300)
plt.show();

# %% [markdown]
# Very little differentiation between classes hear as the ROC

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 902
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   819 non-null    category
# dtypes: category(1)
# memory usage: 7.4 KB

# %%
cvrf = cross_val_score(rf, x, y, cv = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
cvrf
# Out:
# array([0.97560976, 0.97560976, 0.96341463, 1.        , 0.97560976,
#        0.96341463, 0.98780488, 0.98780488, 0.97560976, 0.96296296])

# %%
neigh = KNeighborsClassifier(n_neighbors=4)
neigh.fit(X_train, y_train)
neighpred = neigh.predict(X_test)
neighpred_prob = neigh.predict_proba(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
cm = confusion_matrix(y_test, neighpred)
f1 = f1_score(y_test, neighpred, average='micro')
print("Confusion Matrix\n",cm,"\n")
print("Classification Report\n",(metrics.classification_report(y_test, neighpred, digits=3)))
# Out:
# Confusion Matrix
#  [[47  2  0  0]
#  [ 1 35  0  0]
#  [ 0  1 36  0]
#  [ 0  0  2 40]]
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0      0.979     0.959     0.969        49
#            1      0.921     0.972     0.946        36
#            2      0.947     0.973     0.960        37
#            3      1.000     0.952     0.976        42
#
#     accuracy                          0.963       164
#    macro avg      0.962     0.964     0.963       164
# weighted avg      0.965     0.963     0.964       164

# %%
knnscore = roc_auc_score(y_test, neighpred_prob, multi_class='ovr')
knnscore = .988

# %%
fpr3, tpr3, thresh1 = roc_curve(y_test, neighpred_prob[:,1], pos_label=1)
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)
plt.plot(fpr3, tpr3, linestyle='--',color='purple', label=f"KNN AUC: {knnscore}")
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('KNN ROC',dpi=300)
plt.show();

# %%
knnrf = cross_val_score(neigh, x, y, scoring = "f1_weighted", cv = 20)
knnrf
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# array([1.        , 1.        , 1.        , 0.97554863, 0.95115838,
#        0.97560976, 0.97549813, 0.95110789, 1.        , 0.92682927,
#        1.        , 1.        , 1.        , 0.97554863, 0.97554863,
#        0.97549813, 0.97560976, 0.97549813, 0.97554863, 0.92443229])

# %%
###ALL GRAPHS TOGETHER

# %%
fpr2, tpr2, thresh1 = roc_curve(y_test, rfpred_prob[:,1], pos_label=1)
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)
plt.plot(fpr2, tpr2, linestyle='--',color='green', label=f"Random Forest AUC: {rfscoreround}")
plt.plot(fpr3, tpr3, linestyle='--',color='purple', label=f"KNN AUC: {knnscore}")
plt.plot(fpr4, tpr4, linestyle='--',color='green', label=f"Decision Tree AUC: {dtreernd}")
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label=f"Logistic Regression AUC: {logscore}")
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('Total ROC',dpi=300)
plt.show();

# %%
#train['class'].nunique()

# %%
#train['class'].value_counts()

# %%
#train.info()

# %%
#df["filledin"] = train.groupby("short_name").transform(lambda x: x.fillna(x.mean()))

# %%
#df_final.describe()

# %%
#df_final.info()

# %%
#train.info()

# %%
#nodups = df_final.drop_duplicates()

# %%
#nodups.info

# %%
# get rid of unkowns from all dataframes?
# some columns still have text values in them 
# not merging correctly need to look into how to merge, key is not unique 
# figure out which should be the starting table in the list merge
# could do manually merge one dataframe at a time
