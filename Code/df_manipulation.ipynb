# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install packages
pip install country_converter --upgrade
# Out:
# ...
#      |████████████████████████████████| 50 kB 3.9 MB/s
# ...
#   Created wheel for country-converter: filename=country_converter-0.7.4-py3-none-any.whl size=53543 sha256=60ac71964bf32ad2d5219b8affe8885712afa2bd38c14b7a1d7bbd91ecf7299b
#   Stored in directory: /root/.cache/pip/wheels/69/cf/84/9ebca78737327440a0bb5faa6d0380e9017730534cf0dbcb8c
# Successfully built country-converter
# ...

# %%
# Import packages
import pandas as pd
import country_converter as coco
from google.colab import files

# %%
# Load in data
nuclear = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/raw/Primary-energy-consumption-from-fossilfuels-nuclear-renewables.csv")
temp_country = pd.read_csv("/content/drive/MyDrive/DS320 Final Project/data/raw/GlobalLandTemperaturesByCountry.csv")

# %%
# View data
nuclear.head(10) # Entity = Country
# Out:
#    Entity Code  ...  Renewables (% sub energy)  Nuclear (% sub energy)
# 0  Africa  NaN  ...                      5.537                     0.0
# 1  Africa  NaN  ...                      5.873                     0.0
# 2  Africa  NaN  ...                      6.080                     0.0
# 3  Africa  NaN  ...                      6.743                     0.0
# 4  Africa  NaN  ...                      7.683                     0.0
# 5  Africa  NaN  ...                      8.807                     0.0
# 6  Africa  NaN  ...                      7.677                     0.0
# 7  Africa  NaN  ...                      8.241                     0.0
# 8  Africa  NaN  ...                      8.050                     0.0
# 9  Africa  NaN  ...                      8.735                     0.0
#
# [10 rows x 6 columns]

# %%
# Rename columns
df_nuclear = nuclear.rename(columns = {"Entity":"Country"})

# %%
# Removes any rows with NaN in the columns Country or Year
df_nuclear1 = df_nuclear.dropna(how='any', subset=['Country', 'Year'])

# %%
df_nuclear1["short_name"] = coco.convert(names = df_nuclear1.Country.tolist(), to="name_short", not_found ="Unknown")
# Out:
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# Africa not found in regex
# ...

# %%
# Show continents
continents =  df_nuclear1[df_nuclear1["short_name"].str.contains("Unknown")]
continents = continents["Country"].unique()
print(continents)
# Out:
# ['Africa' 'Europe' 'North America' 'World']

# %%
# View finalized dataframe
df_nuclear1.head(10)
# Out:
#   Country Code  ...  Nuclear (% sub energy)  short_name
# 0  Africa  NaN  ...                     0.0     Unknown
# 1  Africa  NaN  ...                     0.0     Unknown
# 2  Africa  NaN  ...                     0.0     Unknown
# 3  Africa  NaN  ...                     0.0     Unknown
# 4  Africa  NaN  ...                     0.0     Unknown
# 5  Africa  NaN  ...                     0.0     Unknown
# 6  Africa  NaN  ...                     0.0     Unknown
# 7  Africa  NaN  ...                     0.0     Unknown
# 8  Africa  NaN  ...                     0.0     Unknown
# 9  Africa  NaN  ...                     0.0     Unknown
#
# [10 rows x 7 columns]

# %%
# View data
temp_country.head(10) # Make Country first column ... Make a df where dt is Year and it only has the years
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland
# 5  1744-04-01               1.530                          4.680   Åland
# 6  1744-05-01               6.702                          1.789   Åland
# 7  1744-06-01              11.609                          1.577   Åland
# 8  1744-07-01              15.342                          1.410   Åland
# 9  1744-08-01                 NaN                            NaN   Åland

# %%
# Rearrange column order
df_temp_country = temp_country[['Country', 'dt', 'AverageTemperature', 'AverageTemperatureUncertainty']]

# %%
# Removes any rows with NaN in the columns Country or dt
df_temp_country1 = df_temp_country.dropna(how='any', subset=['Country', 'dt'])

# %%
df_temp_country1["short_name"] = coco.convert(names = df_temp_country1.Country.tolist(), to="name_short", not_found ="Unknown")
# Out:
# Streaming output truncated to the last 5000 lines.
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# Palmyra Atoll not found in regex
# ...

# %%
# Show continents
continents1 =  df_temp_country1[df_temp_country1["short_name"].str.contains("Unknown")]
continents1 = continents1["Country"].unique()
print(continents1)
# Out:
# ['Africa' 'Asia' 'Baker Island' 'Europe' 'Kingman Reef' 'North America'
#  'Oceania' 'Palmyra Atoll' 'South America' 'Virgin Islands']

# %%
# View finalized dataframe
df_temp_country1.head(10)
# Out:
#   Country          dt  ...  AverageTemperatureUncertainty     short_name
# 0   Åland  1743-11-01  ...                          2.294  Aland Islands
# 1   Åland  1743-12-01  ...                            NaN  Aland Islands
# 2   Åland  1744-01-01  ...                            NaN  Aland Islands
# 3   Åland  1744-02-01  ...                            NaN  Aland Islands
# 4   Åland  1744-03-01  ...                            NaN  Aland Islands
# 5   Åland  1744-04-01  ...                          4.680  Aland Islands
# 6   Åland  1744-05-01  ...                          1.789  Aland Islands
# 7   Åland  1744-06-01  ...                          1.577  Aland Islands
# 8   Åland  1744-07-01  ...                          1.410  Aland Islands
# 9   Åland  1744-08-01  ...                            NaN  Aland Islands
#
# [10 rows x 5 columns]

# %%
# Save data
df_nuclear1.to_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/Primary-energy-consumption-from-fossilfuels-nuclear-renewables.csv")
df_temp_country1.to_csv("/content/drive/MyDrive/DS320 Final Project/data/interim/GlobalLandTemperaturesByCountry.csv")
